# %%
#Alessandro Figueiredo Gachet
#PÓS-GRADUAÇÃO EM CIÊNCIA DE DADOS - IESB NORTE
#04/12/2018

# %%
# Arquivo 201710_EmissaoPassagens_SCDP.xlsx
#Importando a biblioteca
import pandas as pd

# Ler o arquivo e criar o DataFrame
df = pd.read_excel('201710_EmissaoPassagens_SCDP.xlsx', skiprows=3,skipfooter=3)

#Verificar ass primeiras 5 linhas
df.head()
# Out:
#     Código do órgão superior  \
# 0                          3
# 1                          3
# 2                          3
# 3                          3
# 4                          3
#
#                                  Nome do órgão superior                                  \
# 0   Fundação Instituto Brasileiro de Geografia e ...
# 1   Fundação Instituto Brasileiro de Geografia e ...
# 2   Fundação Instituto Brasileiro de Geografia e ...
# 3   Fundação Instituto Brasileiro de Geografia e ...
# 4   Fundação Instituto Brasileiro de Geografia e ...
#
#     Código do órgão solicitante da viagem  \
# 0                                       3
# 1                                       3
# 2                                       3
# 3                                       3
# 4                                       3
#
#                                         Nome do órgão solicitante da viagem                                         \
# ...

# %%
df.tail()
# Out:
#         Código do órgão superior  \
# 50400                     219924
# 50401                     219924
# 50402                     219924
# 50403                     219924
# 50404                     219924
#
#                                      Nome do órgão superior                                  \
# 50400   Secretaria-Geral da Presidência da República ...
# 50401   Secretaria-Geral da Presidência da República ...
# 50402   Secretaria-Geral da Presidência da República ...
# 50403   Secretaria-Geral da Presidência da República ...
# 50404   Secretaria-Geral da Presidência da República ...
#
#         Código do órgão solicitante da viagem  \
# 50400                                   84010
# 50401                                   84010
# 50402                                   84010
# 50403                                   34889
# 50404                                   34889
#
# ...

# %%
#Tipos das colunas
df.dtypes
# Out:
#  Código do órgão superior                                                                                             int64
#                                Nome do órgão superior                                                                object
#  Código do órgão solicitante da viagem                                                                                int64
#                                       Nome do órgão solicitante da viagem                                            object
#     N. PCDP                                                                                                          object
#  N. Reserva/Localizador                                                                                              object
#   Data Emissão Bilhete                                                                                               object
# ...

# %%
#Tipos e quantidades
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50405 entries, 0 to 50404
# Data columns (total 24 columns):
# Código do órgão superior                 50405 non-null int64
# Nome do órgão superior                   50405 non-null object
# Código do órgão solicitante da viagem    50405 non-null int64
# Nome do órgão solicitante da viagem      50405 non-null object
# N. PCDP                                  50405 non-null object
# N. Reserva/Localizador                   50405 non-null object
# Data Emissão Bilhete                     50405 non-null object
# Data Embarque                            50405 non-null object
# Valor Tarifa Comercial                   50405 non-null float64
# Percentual Desconto Aplicado             50405 non-null float64
# Valor Tarifa Governo                     50405 non-null float64
# Valor Tarifa Embarque                    50405 non-null float64
# Valor Bilhete                            50405 non-null float64
# ...

# %%
#df['densidade_2'] = df['populacao']/ df['area']  Valor Tarifa Comercial Valor Tarifa Governo
df['diferença_tar_Com_X_Gov'] = (df['Valor Tarifa Governo']/df['Valor Tarifa Comercial'])*100

# %%
df['diferença_tar_Com_X_Gov']
# Out:
# 0        100.000000
# 1         97.000000
# 2        100.000000
# 3        100.000000
# 4         96.998386
# 5         96.998604
# 6         97.000000
# 7         97.000000
# 8        100.000000
# 9        100.000000
# 10       100.000000
# 11       100.000000
# 12       100.000000
# 13       100.000000
# 14        93.357947
# 15        97.000000
# 16         0.000000
# 17        97.000000
# 18        97.000000
# 19        96.999648
# 20        96.999627
# 21        96.999584
# 22        96.999408
# 23        96.999589
# 24        96.999166
# 25        96.999459
# 26       100.000000
# 27        94.999727
# 28       100.000000
# 29        94.999727
#             ...
# 50375     97.000000
# 50376     96.999734
# 50377    100.000000
# 50378    100.000000
# 50379     96.999695
# 50380    100.000000
# 50381    100.000000
# 50382     97.000000
# 50383     96.999734
# 50384    100.000000
# 50385     96.999567
# 50386     96.999756
# 50387     96.999756
# 50388     97.000000
# ...

# %%
df['Valor Tarifa Comercial'].value_counts()
# Out:
# 299.00     203
# 349.90     182
# 559.00     180
# 321.90     162
# 389.00     148
# 439.00     144
# 205.00     142
# 199.90     140
# 299.90     127
# 545.00     122
# 555.00     121
# 769.00     121
# 359.00     119
# 619.00     117
# 419.00     115
# 575.00     115
# 405.00     114
# 499.00     112
# 0.00       111
# 269.00     110
# 449.90     108
# 605.00     107
# 1590.90    106
# 425.00     102
# 418.90     102
# 289.90     101
# 1828.90     99
# 475.00      98
# 390.90      97
# 340.90      96
#           ...
# 2701.80      1
# 1355.00      1
# 1059.04      1
# 1656.80      1
# 1073.69      1
# 1107.80      1
# 330.80       1
# 1682.58      1
# 1324.80      1
# 2908.80      1
# 1229.00      1
# 1937.80      1
# 2429.80      1
# 630.10       1
# 1634.00      1
# 320.17       1
# 1110.80      1
# 2241.80      1
# 740.88       1
# 1584.01      1
# 344.80       1
# 2131.96      1
# 1211.80      1
# 2610.80      1
# 2063.80      1
# 1391.95      1
# 1768.05      1
# ...

# %%
# Retirar espaços do inicio dos nomes das colunas
df.rename(columns=lambda x: x.strip(), inplace=True)

# %%
df.dtypes
# Out:
# Código do órgão superior                   int64
# Nome do órgão superior                    object
# Código do órgão solicitante da viagem      int64
# Nome do órgão solicitante da viagem       object
# N. PCDP                                   object
# N. Reserva/Localizador                    object
# Data Emissão Bilhete                      object
# Data Embarque                             object
# Valor Tarifa Comercial                   float64
# Percentual Desconto Aplicado             float64
# Valor Tarifa Governo                     float64
# Valor Tarifa Embarque                    float64
# Valor Bilhete                            float64
# Companhia Aérea                           object
# Classe Tarifária Bilhete                  object
# Regra Tarifária                           object
# No Show                                   object
# Remarcado                                 object
# Cancelado                                 object
# ...

# %%
# Os 5 orgaos que mais solicitaram viagens 'Nome do órgão solicitante da viagem'
df['Nome do órgão solicitante da viagem'].value_counts().head(5)
# Out:
#  Diretoria de Avaliação da Educação Superior                                                                        1988
#  Gabinete                                                                                                           1833
#  Reitoria                                                                                                           1499
#  Pró-Reitoria de Pesquisa e Pós-Graduação                                                                           1078
#  Grupamento de Apoio de Brasília                                                                                     830
# Name: Nome do órgão solicitante da viagem, dtype: int64

# %%
# %matplotlib inline

# %%
# Emissão de passagens por companhia aerea
df['Companhia Aérea'].value_counts().plot.barh()

# %%
df['Situação Final Bilhete'].unique()
# Out:
# array([' Voado', ' Andamento', ' Cancelado'], dtype=object)

# %%
df['Nome do órgão solicitante da viagem'].value_counts().head(5)
# Out:
#  Diretoria de Avaliação da Educação Superior                                                                        1988
#  Gabinete                                                                                                           1833
#  Reitoria                                                                                                           1499
#  Pró-Reitoria de Pesquisa e Pós-Graduação                                                                           1078
#  Grupamento de Apoio de Brasília                                                                                     830
# Name: Nome do órgão solicitante da viagem, dtype: int64

# %%
#Valores dos bilhetes
df['Valor Bilhete'].describe()
# Out:
# count    50405.000000
# mean       694.855817
# std        424.865564
# min          0.000000
# 25%        387.340000
# 50%        591.430000
# 75%        890.360000
# max       4083.610000
# Name: Valor Bilhete, dtype: float64

# %%
df['Valor Bilhete'].max()
# Out:
# 4083.61

# %%
#Bilhete de maior valor
df[df['Valor Bilhete'] == df['Valor Bilhete'].max()]
# Out:
#        Código do órgão superior  \
# 21541                       431
#
#                                   Nome do órgão superior  \
# 21541   Universidade Federal de Santa Maria          ...
#
#        Código do órgão solicitante da viagem  \
# 21541                                  27563
#
#                      Nome do órgão solicitante da viagem          N. PCDP  \
# 21541   Pró-Reitoria de Pós-Graduação e Pesquisa     ...   004488/17
#
#          N. Reserva/Localizador      Data Emissão Bilhete  \
# 21541   OBF73Z                    2017-10-30 10:00:57.624
#
#               Data Embarque  Valor Tarifa Comercial  \
# 21541   2017-11-06 06:10:00                  4156.8
#
#        Percentual Desconto Aplicado           ...             \
# 21541                           3.0           ...
#
#          Classe Tarifária Bilhete  \
# 21541   Y,Y,Y/G,G,G
#
#                                          Regra Tarifária    No Show  \
# ...

# %%
# As 10 maiores bilhetes
df.nlargest(10, 'Valor Bilhete')
# Out:
#        Código do órgão superior  \
# 21541                       431
# 14489                       324
# 14490                       324
# 29221                      1799
# 29222                      1799
# 29223                      1799
# 14558                       324
# 32060                      1929
# 28400                       704
# 24807                       470
#
#                                   Nome do órgão superior  \
# 21541   Universidade Federal de Santa Maria          ...
# 14489   Departamento de Polícia Federal              ...
# 14490   Departamento de Polícia Federal              ...
# 29221   Instituto Nacional de Colonização e Reforma A...
# 29222   Instituto Nacional de Colonização e Reforma A...
# 29223   Instituto Nacional de Colonização e Reforma A...
# 14558   Departamento de Polícia Federal              ...
# 32060   Ministério da Fazenda                        ...
# 28400   Departamento de Polícia Rodoviária Federal   ...
# ...

# %%
# As 10 maiores bilhetes
df.nlargest(10, 'No Show')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-9879cb143cee> in <module>()
#       1 # As 10 maiores bilhetes
# ----> 2 df.nlargest(10, 'No Show')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in nlargest(self, n, columns, keep)
#    3775                                        n=n,
#    3776                                        keep=keep,
# -> 3777                                        columns=columns).nlargest()
#    3778
#    3779     def nsmallest(self, n, columns, keep='first'):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\algorithms.py in nlargest(self)
#     915
#     916     def nlargest(self):
# --> 917         return self.compute('nlargest')
#     918
#     919     def nsmallest(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\algorithms.py in compute(self, method)
# ...

# %%
#Listagem por Nome do órgão superior , Nome do órgão solicitante da viagem , Companhia Aérea
df.pivot_table('Código do órgão superior',index=["Nome do órgão superior","Nome do órgão solicitante da viagem","Companhia Aérea"],aggfunc='count',margins=True)
# Out:
#                                                                                                                                               Código do órgão superior
# Nome do órgão superior                             Nome do órgão solicitante da viagem                Companhia Aérea
#  Advocacia-Geral da União                      ...  Advocacia-Geral da União                      ...  GOL Linhas Aéreas Inteligentes                                2
#                                                                                                        LATAM AIRLINES BRASIL                                         2
#                                                     Conselho Superior da Advocacia-Geral da União ...  GOL Linhas Aéreas Inteligentes                                3
#                                                                                                        LATAM AIRLINES BRASIL                                         2
# ...
